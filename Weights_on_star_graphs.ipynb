# %%
from ipynb.fs.defs.functions import *

from datetime import datetime
import networkx as nx
import math
import numpy as np
import random
import matplotlib.pyplot as plt
from networkx.algorithms import bipartite
import sys
import contextlib
import itertools
from math import comb
from numpy import linalg as LA
import math
from numpy.linalg import matrix_power
import matplotlib.pyplot as plt
from math import factorial as f
import networkx as nx
import itertools
import time
import pandas as pd
import random as rnd

def theoretic_fixation_moran(nodes,fitness):
    if fitness==1:
        return 1/(nodes)
    else:
        k=(1-1/fitness)/(1-1/(pow(fitness,nodes)))
        return k

# %%
m1=22
m2=23
w=24

weighted_star_solver(m1,m2,w/4,1)-1/(m1+m2+1)
# Out:
# 1.1071005223683983e-14

# %%
star_2_18_1 =[weighted_star_solver(2,18,1,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_2_18_2 =[weighted_star_solver(2,18,2,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_2_18_4 =[weighted_star_solver(2,18,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_2_18_8 =[weighted_star_solver(2,18,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_2_18_16 =[weighted_star_solver(2,18,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_2_18_32 =[weighted_star_solver(2,18,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_2_18_100 =[weighted_star_solver(2,18,100,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_4_16_2 =[weighted_star_solver(4,16,2,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_4_16_4 =[weighted_star_solver(4,16,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_4_16_8 =[weighted_star_solver(4,16,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_4_16_16 =[weighted_star_solver(4,16,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_4_16_32 =[weighted_star_solver(4,16,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_4_16_100 =[weighted_star_solver(4,16,100,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_8_12_2 =[weighted_star_solver(8,12,2,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_8_12_4 =[weighted_star_solver(8,12,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_8_12_8 =[weighted_star_solver(8,12,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_8_12_16 =[weighted_star_solver(8,12,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_8_12_32 =[weighted_star_solver(8,12,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_8_12_100 =[weighted_star_solver(8,12,100,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_10_10_2 =[weighted_star_solver(10,10,2,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_10_10_4 =[weighted_star_solver(10,10,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_10_10_8 =[weighted_star_solver(10,10,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_10_10_16 =[weighted_star_solver(10,10,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_10_10_32 =[weighted_star_solver(10,10,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_10_10_100 =[weighted_star_solver(10,10,100,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_14_6_2 =[weighted_star_solver(14,6,2,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_14_6_4 =[weighted_star_solver(14,6,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_14_6_8 =[weighted_star_solver(14,6,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_14_6_16 =[weighted_star_solver(14,6,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_14_6_32 =[weighted_star_solver(14,6,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_14_6_100 =[weighted_star_solver(14,6,100,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_18_2_2 =[weighted_star_solver(18,2,2,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_18_2_4 =[weighted_star_solver(18,2,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_18_2_8 =[weighted_star_solver(18,2,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_18_2_16 =[weighted_star_solver(18,2,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_18_2_32 =[weighted_star_solver(18,2,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]
star_18_2_100 =[weighted_star_solver(18,2,100,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_5_15_2 =[weighted_star_solver(5,15,2,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]
star_5_15_10 =[weighted_star_solver(5,15,10,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]
#star_5_15_8 =[weighted_star_solver(4,16,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
#star_5_15_16 =[weighted_star_solver(4,16,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
#star_5_15_32 =[weighted_star_solver(4,16,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
star_5_15_100 =[weighted_star_solver(5,15,100,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]

# %%
star_10_10_2 =[weighted_star_solver(10,10,2,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]
star_10_10_10 =[weighted_star_solver(10,10,10,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]
#star_5_15_8 =[weighted_star_solver(4,16,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
#star_5_15_16 =[weighted_star_solver(4,16,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
#star_5_15_32 =[weighted_star_solver(4,16,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
star_10_10_100 =[weighted_star_solver(10,10,100,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]

# %%
star_15_5_2 =[weighted_star_solver(15,5,2,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]
star_15_5_10 =[weighted_star_solver(15,5,10,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]
#star_5_15_8 =[weighted_star_solver(4,16,8,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
#star_5_15_16 =[weighted_star_solver(4,16,16,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
#star_5_15_32 =[weighted_star_solver(4,16,32,i/10)-theoretic_fixation_moran(20,i/10) for i in range(50,200)]
star_15_5_100 =[weighted_star_solver(15,5,100,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]

# %%
star_15_5_1 =[weighted_star_solver(15,5,1,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200)]

# %%
np.save('star_15_5_1.npy',star_15_5_1)

# %%
np.save('star_5_15_2.npy',star_5_15_2)
np.save('star_5_15_10.npy',star_5_15_10)
np.save('star_5_15_100.npy',star_5_15_100)

# %%
np.save('star_10_10_2.npy',star_10_10_2)
np.save('star_10_10_10.npy',star_10_10_10)
np.save('star_10_10_100.npy',star_10_10_100)


np.save('star_15_5_2.npy',star_15_5_2)
np.save('star_15_5_10.npy',star_15_5_10)
np.save('star_15_5_100.npy',star_15_5_100)

# %%
star_5_15_2=np.load('star_5_15_2.npy', allow_pickle =True)
star_5_15_10=np.load('star_5_15_10.npy', allow_pickle =True)
star_5_15_100=np.load('star_5_15_100.npy', allow_pickle =True)



star_10_10_2=np.load('star_10_10_2.npy', allow_pickle =True)
star_10_10_10=np.load('star_10_10_10.npy', allow_pickle =True)
star_10_10_100=np.load('star_10_10_100.npy', allow_pickle =True)


star_15_5_2=np.load('star_15_5_2.npy',allow_pickle =True)
star_15_5_10=np.load('star_15_5_10.npy',allow_pickle =True)
star_15_5_100=np.load('star_15_5_100.npy',allow_pickle =True)

star_15_5_1=np.load('star_15_5_1.npy',allow_pickle =True)

# %%
w_40_star=np.load('w_40_star.npy',allow_pickle =True)

# %%
star_8_12_4 =[weighted_star_solver(8,12,4,i/10)-theoretic_fixation_moran(20,i/10) for i in range(1,20)]

# %%
star_2_18_1[16]-star_2_18_2[16]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5ed65336c2ed> in <module>
# ----> 1 star_2_18_1[16]-star_2_18_2[16]
#
# NameError: name 'star_2_18_1' is not defined

# %% [markdown]
# ## Plots

# %%
k=20
plt.figure(figsize=(8, 8))
plt.plot([i/10 for i in range(1,20)],star_2_18_1,label='unweighted ',color='black')
#plt.plot([i/10 for i in range(1,20)],star_2_18_2,label='$w=2$ ')
#plt.plot([i/10 for i in range(1,20)],star_2_18_4,label='$w=4$ ')
#plt.plot([i/10 for i in range(1,20)],star_2_18_8,label='$w=8$ ')
plt.plot([i/10 for i in range(1,20)],star_2_18_16,label='$w=16, N_1=2,N_2=18$ ')
#plt.plot([i/10 for i in range(1,20)],star_2_18_32,label='$w=32$ ')
plt.plot([i/10 for i in range(1,20)],star_2_18_100,label='$w=100,N_1=2,N_2=18$ ')


plt.plot([i/10 for i in range(1,20)],star_4_16_16,label='$w=16, N_1=4,N_2=16$ ')
plt.plot([i/10 for i in range(1,20)],star_4_16_100,label='$w=100,N_1=4,N_2=16$ ')

plt.plot([i/10 for i in range(1,20)],star_8_12_16,label='$w=16, N_1=8,N_2=12$ ')
plt.plot([i/10 for i in range(1,20)],star_8_12_100,label='$w=100,N_1=8,N_2=12$ ')

plt.plot([i/10 for i in range(1,20)],star_10_10_16,label='$w=16, N_1=10,N_2=10$ ')
plt.plot([i/10 for i in range(1,20)],star_10_10_100,label='$w=100,N_1=10,N_2=10$ ')


plt.plot([i/10 for i in range(1,20)],star_14_6_16,label='$w=16, N_1=14,N_2=6$ ')
plt.plot([i/10 for i in range(1,20)],star_14_6_100,label='$w=100,N_1=14,N_2=6$ ')


#plt.plot([i/10 for i in range(1,20)],star_18_2_16,label='$w=16, N_1=18,N_2=2$ ')
#plt.plot([i/10 for i in range(1,20)],star_18_2_100,label='$w=100,N_1=18,N_2=2$ ')

plt.axhline(y = 0, color = 'black', linestyle = '--')
plt.title('Weighted star with $20$ nodes',fontsize=22)
plt.xlabel('fitness',fontsize=22)
plt.ylabel('Difference from Moran',fontsize=22)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming star_2_18_1, star_2_18_16, star_2_18_100, etc., are defined

plt.figure(figsize=(10,8))

# Plot each line with a distinct style

plt.plot([i/10 for i in range(1, 20)], star_2_18_16, label='$w=16, N_1=2,N_2=18$', linestyle='--', marker='^')
plt.plot([i/10 for i in range(1, 20)], star_2_18_100, label='$w=100,N_1=2,N_2=18$', linestyle='-.', marker='s')

plt.plot([i/10 for i in range(1, 20)], star_4_16_16, label='$w=16, N_1=4,N_2=16$', linestyle=':', marker='d')
plt.plot([i/10 for i in range(1, 20)], star_4_16_100, label='$w=100,N_1=4,N_2=16$', linestyle='-', marker='x')

plt.plot([i/10 for i in range(1, 20)], star_8_12_16, label='$w=16, N_1=8,N_2=12$', linestyle='--', marker='+')
plt.plot([i/10 for i in range(1, 20)], star_8_12_100, label='$w=100,N_1=8,N_2=12$', linestyle='-.', marker='*')

plt.plot([i/10 for i in range(1, 20)], star_10_10_16, label='$w=16, N_1=10,N_2=10$', linestyle=':', marker='|')
plt.plot([i/10 for i in range(1, 20)], star_10_10_100, label='$w=100,N_1=10,N_2=10$', linestyle='-', marker='_')

plt.plot([i/10 for i in range(1, 20)], star_14_6_16, label='$w=16, N_1=14,N_2=6$', linestyle='--', marker='p')
plt.plot([i/10 for i in range(1, 20)], star_14_6_100, label='$w=100,N_1=14,N_2=6$', linestyle='-.', marker='h')
plt.plot([i/10 for i in range(1, 20)], star_2_18_1, label='unweighted', color='black', linestyle='-', marker='o')
# Reference lines
plt.axhline(y=0, color='black', linestyle='--')
plt.axvline(x=1, color='black', linestyle='--')
# Titles and labels
#plt.title('Weighted Star with $20$ Nodes', fontsize=22)
plt.xlabel('$r$', fontsize=22)
plt.ylabel('Difference from Moran', fontsize=22)

# Legend
plt.legend(fontsize=10)

# Grid
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# Save the figure with high DPI
plt.savefig('weighted_star_20_nodes.pdf', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.gridspec as gridspec

# Load the provided image
#image_path = '/mnt/data/edge_weight_2_networks.png'
#network_image = Image.open(image_path)

# Create dummy data for the plots since the actual data is not provided
#k = 300
#four_nodes = np.random.normal(0, 1, k-1)  # Normal distribution centered around 0
#five_nodes = np.random.normal(0, 1, k-1)
#six_nodes = np.random.normal(0, 1, k-1)
#seven_nodes = np.random.normal(0, 1, k-1)
#eight_nodes = np.random.normal(0, 1, k-1)

# Set up a grid for the subplots to be side by side (horizontal)
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 2])

# Place the network image in the first subplot
ax0 = plt.subplot(gs[0])
ax0.imshow(com_2_weight)
ax0.axis('off')  # Hide axes

# Plot the generated data in the second subplot
ax1 = plt.subplot(gs[1])
ax1.plot([i/100 for i in range(1, k)], four_nodes, label='$N=4$')
ax1.plot([i/100 for i in range(1, k)], five_nodes, label='$N=5$')
ax1.plot([i/100 for i in range(1, k)], six_nodes, label='$N=6$')
ax1.plot([i/100 for i in range(1, k)], seven_nodes, label='$N=7$')
ax1.plot([i/100 for i in range(1, k)], eight_nodes, label='$N=8$')
ax1.axhline(y=0, color='black', linestyle='--')
ax1.axvline(x=1, color='black', linestyle='--')

# Enhance the plot
ax1.set_xlabel('$r$', fontsize=28)
ax1.set_ylabel('Difference from Moran', fontsize=28)
ax1.tick_params(axis='both', which='major', labelsize=22)
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax1.legend(fontsize=22)
plt.tight_layout()

plt.savefig('edge_weight_2_combined.pdf', bbox_inches="tight")
# Show the figure
plt.show()

# %%
import matplotlib.image as mpimg

# Now you can use mpimg.imread to read the image file
star_weight = mpimg.imread('edge_star_networks_vertical.png')

# %%
import matplotlib.image as mpimg

# Now you can use mpimg.imread to read the image file
star_weight = mpimg.imread('edge_weight_star_graph.png')

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.gridspec as gridspec



# Set up a grid for the subplots to be side by side (horizontal)
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(1, 2, width_ratios=[1, 2])

# Place the network image in the first subplot
ax0 = plt.subplot(gs[0])
ax0.imshow(star_weight)
ax0.axis('off')  # Hide axes

# Plot the generated data in the second subplot
ax1 = plt.subplot(gs[1])

ax1.plot([i/10 for i in range(1, 20)], star_2_18_16, label='$w=16, N_1=2,N_2=18$', linestyle='--', marker='^')
ax1.plot([i/10 for i in range(1, 20)], star_2_18_100, label='$w=100,N_1=2,N_2=18$', linestyle='-.', marker='s')

ax1.plot([i/10 for i in range(1, 20)], star_4_16_16, label='$w=16, N_1=4,N_2=16$', linestyle=':', marker='d')
ax1.plot([i/10 for i in range(1, 20)], star_4_16_100, label='$w=100,N_1=4,N_2=16$', linestyle='-', marker='x')

ax1.plot([i/10 for i in range(1, 20)], star_8_12_16, label='$w=16, N_1=8,N_2=12$', linestyle='--', marker='+')
ax1.plot([i/10 for i in range(1, 20)], star_8_12_100, label='$w=100,N_1=8,N_2=12$', linestyle='-.', marker='*')

ax1.plot([i/10 for i in range(1, 20)], star_10_10_16, label='$w=16, N_1=10,N_2=10$', linestyle=':', marker='|')
ax1.plot([i/10 for i in range(1, 20)], star_10_10_100, label='$w=100,N_1=10,N_2=10$', linestyle='-', marker='_')

ax1.plot([i/10 for i in range(1, 20)], star_14_6_16, label='$w=16, N_1=14,N_2=6$', linestyle='--', marker='p')
ax1.plot([i/10 for i in range(1, 20)], star_14_6_100, label='$w=100,N_1=14,N_2=6$', linestyle='-.', marker='h')
ax1.plot([i/10 for i in range(1, 20)], star_2_18_1, label='unweighted', color='black', linestyle='-', marker='o')
# Reference lines
ax1.axhline(y=0, color='black', linestyle='--')
ax1.axvline(x=1, color='black', linestyle='--')
# Titles and labels
# Enhance the plot
ax1.set_xlabel('$r$', fontsize=28)
ax1.set_ylabel('Difference from Moran', fontsize=28)
ax1.tick_params(axis='both', which='major', labelsize=22)
ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax1.legend(fontsize=22)

# Legend
plt.legend(fontsize=10)

# Grid
plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# Save the figure with high DPI
plt.savefig('weighted_star_20_nodes.pdf', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.gridspec as gridspec



# Set up a grid for the subplots to be side by side (horizontal)
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(1, 2, width_ratios=[1.25, 2])

# Place the network image in the first subplot
ax0 = plt.subplot(gs[0])
ax0.imshow(star_weight)
ax0.axis('off')  # Hide axes

# Plot the generated data in the second subplot
ax1 = plt.subplot(gs[1])

ax1.plot([i/100 for i in range(50, 200)], star_5_15_2, label='$w=2, N_1=5,N_2=15$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_10, label='$w=10, N_1=5,N_2=15$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_100, label='$w=100, N_1=5,N_2=15$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_10_10_2, label='$w=2, N_1=10,N_2=10$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_10, label='$w=10, N_1=10,N_2=10$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_100, label='$w=100, N_1=10,N_2=10$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_15_5_2, label='$w=2, N_1=5,N_2=15$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_10, label='$w=10, N_1=5,N_2=15$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_100, label='$w=100, N_1=5,N_2=15$')#, linestyle='-.')

#ax1.plot([i/10 for i in range(1, 20)], star_10_10_16, label='$w=16, N_1=10,N_2=10$', linestyle=':', marker='|')
#ax1.plot([i/10 for i in range(1, 20)], star_10_10_100, label='$w=100,N_1=10,N_2=10$', linestyle='-', marker='_')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_1, label='Unweighted', color='black', linestyle='-')
# Reference lines
ax1.axhline(y=0, color='black', linestyle='--')
ax1.axvline(x=1, color='black', linestyle='--')
# Titles and labels
# Enhance the plot
ax1.set_xlabel('$r$', fontsize=28)
ax1.set_ylabel('Difference from Moran', fontsize=28)
ax1.tick_params(axis='both', which='major', labelsize=22)
#ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax1.legend(fontsize=22)
ax1.set_xlim([0.5-0.02, 2.0+0.02])
ax1.set_xlim([0.5-0.02, 2.0+0.02])
# Legend
plt.legend(fontsize=10)

fig.text(0.06, 0.92, '(a)', fontsize=25)
fig.text(0.4, 0.92, '(b)', fontsize=25)

plt.subplots_adjust( wspace=0.4)#, hspace=0.4)

# Grid
#plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# Save the figure with high DPI
plt.savefig('weighted_star_20_nodes.pdf', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %% [markdown]
# ### Heatmap

# %%
    w_40_star =  np.zeros((10,100,100), dtype=object)
    ### Generate the 100 connected random graphs
    ### Each of 100 graph will have 100 random weighted versions
    start_time = datetime.now()
    fitness = [0.9,1.3]
    for i in range(1,39):
        for weight in range(2,50):
            for k in range(2):#print(i,j,k)
                w_40_star[k][i][weight]=weighted_star_solver(i,39-i,weight,fitness[k])-theoretic_fixation_moran(40,fitness[k])
        end_time = datetime.now()
        print('Duration: {}'.format(end_time - start_time))
        np.save('w_40_star.npy',w_40_star)
            
    np.save('w_40_star.npy',w_40_star)
# Out:
# Duration: 0:04:46.259375
# Duration: 0:12:29.482803
# Duration: 0:22:56.376053
# Duration: 0:35:43.394958
# Duration: 0:51:09.842806
# Duration: 1:08:47.417689
# Duration: 1:29:11.793555
# Duration: 1:51:15.777820
# Duration: 2:15:21.358569
# Duration: 2:41:24.122538
# Duration: 3:08:40.382838
# Duration: 3:36:11.602770
# Duration: 4:05:08.134972
# Duration: 4:35:30.949509
# Duration: 5:06:31.554555

# %%
weighted_star_solver(15,5,1,i/100)-theoretic_fixation_moran(20,i/100) for i in range(50,200

# %%
start_time = datetime.now()
weighted_star_solver(35,4,1,1)
end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Duration: 0:00:08.296151

# %%
8*39*48*2/3600
# Out:
# 8.32

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import matplotlib.gridspec as gridspec



# Set up a grid for the subplots to be side by side (horizontal)
fig = plt.figure(figsize=(18, 10))
gs = gridspec.GridSpec(1, 2, width_ratios=[1.25, 2])

# Place the network image in the first subplot
ax0 = plt.subplot(gs[0])
ax0.imshow(star_weight)
ax0.axis('off')  # Hide axes

# Plot the generated data in the second subplot
ax1 = plt.subplot(gs[1])

ax1.plot([i/100 for i in range(50, 200)], star_5_15_2, label='$w=2, N_1=5,N_2=15$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_10, label='$w=10, N_1=5,N_2=15$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_100, label='$w=100, N_1=5,N_2=15$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_10_10_2, label='$w=2, N_1=10,N_2=10$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_10, label='$w=10, N_1=10,N_2=10$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_100, label='$w=100, N_1=10,N_2=10$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_15_5_2, label='$w=2, N_1=5,N_2=15$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_10, label='$w=10, N_1=5,N_2=15$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_100, label='$w=100, N_1=5,N_2=15$')#, linestyle='-.')

#ax1.plot([i/10 for i in range(1, 20)], star_10_10_16, label='$w=16, N_1=10,N_2=10$', linestyle=':', marker='|')
#ax1.plot([i/10 for i in range(1, 20)], star_10_10_100, label='$w=100,N_1=10,N_2=10$', linestyle='-', marker='_')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_1, label='Unweighted', color='black', linestyle='-')
# Reference lines
ax1.axhline(y=0, color='black', linestyle='--')
ax1.axvline(x=1, color='black', linestyle='--')
# Titles and labels
# Enhance the plot
ax1.set_xlabel('$r$', fontsize=28)
ax1.set_ylabel('Difference from Moran', fontsize=28)
ax1.tick_params(axis='both', which='major', labelsize=22)
#ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax1.legend(fontsize=22)
ax1.set_xlim([0.5-0.02, 2.0+0.02])
ax1.set_xlim([0.5-0.02, 2.0+0.02])
# Legend
plt.legend(fontsize=10)

fig.text(0.06, 0.92, '(a)', fontsize=25)
fig.text(0.4, 0.92, '(b)', fontsize=25)

plt.subplots_adjust( wspace=0.4)#, hspace=0.4)

# Grid
#plt.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=0.7)

# Save the figure with high DPI
plt.savefig('weighted_star_20_nodes.pdf', dpi=300, bbox_inches='tight')

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec

# Assuming 'star_weight', 'star_5_15_2', ..., 'star_15_5_1', and 'w_40_star' are defined

# Set up a 2x2 grid
fig = plt.figure(figsize=(25, 20))
gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1])

# First subplot (existing network image)
ax0 = plt.subplot(gs[0, 0])
ax0.imshow(star_weight)
ax0.axis('off')


# Second subplot (existing line plot)
ax1 = plt.subplot(gs[0, 1])

ax1.plot([i/100 for i in range(50, 200)], star_5_15_2, label='$w=2, N_1=5,N_2=15$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_10, label='$w=10, N_1=5,N_2=15$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_100, label='$w=100, N_1=5,N_2=15$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_10_10_2, label='$w=2, N_1=10,N_2=10$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_10, label='$w=10, N_1=10,N_2=10$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_100, label='$w=100, N_1=10,N_2=10$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_15_5_2, label='$w=2, N_1=5,N_2=15$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_10, label='$w=10, N_1=5,N_2=15$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_100, label='$w=100, N_1=5,N_2=15$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_15_5_1, label='Unweighted', color='black', linestyle='-')
# Reference lines
ax1.axhline(y=0, color='black')#, linestyle='--')
ax1.axvline(x=1, color='black', linestyle='--')
# Titles and labels
# Enhance the plot
ax1.set_xlabel('$r$', fontsize=28)
ax1.set_ylabel('Difference from Moran', fontsize=28)
ax1.tick_params(axis='both', which='major', labelsize=22)
#ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
ax1.legend(fontsize=10)
ax1.set_xlim([0.5-0.02, 2.0+0.02])
ax1.set_xlim([0.5-0.02, 2.0+0.02])



# Third subplot (heatmap 1)
ax2 = plt.subplot(gs[1, 0])
heatmap1 = ax2.imshow(
    np.array(w_40_star[0][2:39, 2:50], dtype=float), 
    cmap='coolwarm', 
    interpolation='nearest', 
    aspect='auto', 
    extent=[2, 49, 38, 2]  # adjust these values as needed
)
divider1 = make_axes_locatable(ax2)
cax1 = divider1.append_axes("right", size="5%", pad=0.5)
cbar1 = fig.colorbar(heatmap1, cax=cax1)
cbar1.ax.tick_params(labelsize=14)
#contour_level1 = -0.0015935962097524228
#ax2.contour(np.array(w_40_star[0][2:39, 2:50], dtype=float), levels=[contour_level1], colors='blue', linestyles='solid')#,extent=[2, 49, 38, 2])
level_to_mark1 = -0.0015935962097524228
cbar1.ax.axhline(y=level_to_mark1, color='magenta', linestyle='solid')



# Fourth subplot (heatmap 2)
ax3 = plt.subplot(gs[1, 1])
heatmap2 = ax3.imshow(
    np.array(w_40_star[1][2:39, 2:50], dtype=float), 
    cmap='coolwarm', 
    interpolation='nearest', 
    aspect='auto', 
    extent=[2, 49, 38, 2]  # adjust these values as needed
)
divider2 = make_axes_locatable(ax3)
cax2 = divider2.append_axes("right", size="5%", pad=0.5)
cbar2 = fig.colorbar(heatmap2, cax=cax2)
cbar2.ax.tick_params(labelsize=14)
# Mark a specific level on the colorbar of heatmap2
level_to_mark2 = 0.15993081805569867
cbar2.ax.axhline(y=level_to_mark2, color='magenta', linestyle='solid')
# Adding contour to heatmap2
#contour_level2 = 0.15993081805569867
#ax3.contour(np.array(w_40_star[1][2:39, 2:50], dtype=float), levels=[contour_level2], colors='blue', linestyles='solid', 
    #extent=[2, 49, 38, 2])



# Adjust layout and save the figure
plt.subplots_adjust(wspace=0.3, hspace=0.2)


##axes labels
#axs[0,0].set_xlabel('$r$',fontsize=30)
ax1.set_xlabel('$r$',fontsize=30)
ax2.set_xlabel('$w$',fontsize=30)
ax3.set_xlabel('$w$',fontsize=30)

#axs[0,0].set_ylabel('Difference from Moran',fontsize=30)
#axs[0,1].set_ylabel('$r$',fontsize=25)
ax2.set_ylabel('$N_1$',fontsize=30)
ax3.set_ylabel('$N_1$',fontsize=30)

#axs[0,0].tick_params(axis='x', labelsize=20)
ax2.tick_params(axis='x', labelsize=20) 
ax1.tick_params(axis='x', labelsize=20) 
ax3.tick_params(axis='x', labelsize=20)
#axs[0,0].tick_params(axis='y', labelsize=20)
ax2.tick_params(axis='y', labelsize=20) 
ax1.tick_params(axis='y', labelsize=20) 
ax3.tick_params(axis='y', labelsize=20)# Change xtick label size
# Adjust layout and save the figure
#plt.tight_layout()

# labels
fig.text(0.1, 0.9, '(a)', fontsize=25)
fig.text(0.536, 0.9, '(b)', fontsize=25)
fig.text(0.1, 0.482, '(c)', fontsize=25)
fig.text(0.536, 0.482, '(d)', fontsize=25)

plt.savefig('complete_weighted_star_40.pdf', dpi=300, bbox_inches='tight')
# Show the figure
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import TwoSlopeNorm
from mpl_toolkits.axes_grid1 import make_axes_locatable




# Assuming 'star_weight', 'star_5_15_2', ..., 'star_15_5_1', and 'w_40_star' are defined

# Set up a 2x2 grid
fig = plt.figure(figsize=(25, 20))
gs = gridspec.GridSpec(2, 2, width_ratios=[1, 1])

# First subplot (existing network image)
ax0 = plt.subplot(gs[0, 0])
ax0.imshow(star_weight)
ax0.axis('off')


# Second subplot (existing line plot)
ax1 = plt.subplot(gs[0, 1])

ax1.plot([i/100 for i in range(50, 200)], star_5_15_2, label='$w=2, N_1=5,N_2=14$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_10, label='$w=10, N_1=5,N_2=14$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_5_15_100, label='$w=100, N_1=5,N_2=14$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_10_10_2, label='$w=2, N_1=10,N_2=9$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_10, label='$w=10, N_1=10,N_2=9$')#, linestyle='--')
ax1.plot([i/100 for i in range(50, 200)], star_10_10_100, label='$w=100, N_1=10,N_2=9$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_15_5_2, label='$w=2, N_1=15,N_2=4$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_10, label='$w=10, N_1=15,N_2=4$')
ax1.plot([i/100 for i in range(50, 200)], star_15_5_100, label='$w=100, N_1=15,N_2=4$')#, linestyle='-.')

ax1.plot([i/100 for i in range(50, 200)], star_15_5_1, label='Unweighted', color='black', linestyle='-')
# Reference lines
ax1.axhline(y=0, color='black')#, linestyle='--')
ax1.axvline(x=1, color='black', linestyle='dotted')
# Titles and labels
# Enhance the plot
ax1.set_xlabel('$r$', fontsize=28)
ax1.set_ylabel('Difference from Moran', fontsize=40)
ax1.tick_params(axis='both', which='major', labelsize=22)
#ax1.grid(True, which='both', linestyle='--', linewidth=0.5)
# Customize the legend's location and make it opaque
# Also setting an edgecolor for clarity
ax1.legend(fontsize=15, loc='upper left', framealpha=1.0, edgecolor='black')

ax1.set_xlim([0.5-0.02, 1.99])
ax1.set_xlim([0.5-0.02, 1.99])


transition_value = -0.0015935962097524228



# Setting the normalization with the specific transition value
norm = TwoSlopeNorm(vcenter=transition_value, vmin=w_40_star[0][2:39, 2:50].min(), vmax=w_40_star[0][2:39, 2:50].max())

from matplotlib.colors import LinearSegmentedColormap

# Define a binary color scheme with distinct colors on either side of the transition value
# Colors chosen: Blue for values below the transition, Red for values above
colors = ["blue","white", "red"]  # Blue for negative, Red for positive relative to the transition value
cmap = LinearSegmentedColormap.from_list("custom_binary", colors, N=60)
# Third subplot (heatmap 1)
ax2 = plt.subplot(gs[1, 0])
heatmap1 = ax2.imshow(
    np.array(w_40_star[0][2:39, 2:50], dtype=float), 
    cmap=cmap, 
    interpolation='nearest', 
    aspect='auto', 
    extent=[2, 50, 38, 2] , norm=norm # adjust these values as needed
)
divider1 = make_axes_locatable(ax2)
cax1 = divider1.append_axes("right", size="5%", pad=0.5)
cbar1 = fig.colorbar(heatmap1, cax=cax1)
cbar1.ax.tick_params(labelsize=14)
#plt.contour(w_40_star[0][2:39, 2:50], levels=[transition_value], colors='black', linewidths=1.5)
#contour_level1 = -0.0015935962097524228
#ax2.contour(np.array(w_40_star[0][2:39, 2:50], dtype=float), levels=[contour_level1], colors='blue', linestyles='solid')#,extent=[2, 49, 38, 2])
level_to_mark1 = -0.0015935962097524228
cbar1.ax.axhline(y=level_to_mark1, color='black', linestyle='solid')


transition_value = 0.15993081805569867
#transition_value = 0.16
norm1 = TwoSlopeNorm(vcenter=transition_value, vmin=w_40_star[1][2:39, 2:50].min(), vmax=w_40_star[1][2:39, 2:50].max())
cmap1 = LinearSegmentedColormap.from_list("custom_binary", colors, N=40)
# Fourth subplot (heatmap 2)
ax3 = plt.subplot(gs[1, 1])
heatmap2 = ax3.imshow(
    np.array(w_40_star[1][2:39, 2:50], dtype=float), 
    cmap=cmap1, 
    interpolation='nearest', 
    aspect='auto', 
    extent=[2, 50, 38, 2], norm=norm1  # adjust these values as needed
)
divider2 = make_axes_locatable(ax3)
cax2 = divider2.append_axes("right", size="5%", pad=0.5)
cbar2 = fig.colorbar(heatmap2, cax=cax2)
cbar2.ax.tick_params(labelsize=14)
# Mark a specific level on the colorbar of heatmap2

level_to_mark2 = transition_value-0.0001
cbar2.ax.axhline(y=level_to_mark2, color='black', linestyle='solid')
# Adding contour to heatmap2
#contour_level2 = 0.15993081805569867
#ax3.contour(np.array(w_40_star[1][2:39, 2:50], dtype=float), levels=[contour_level2], colors='blue', linestyles='solid', 
    #extent=[2, 49, 38, 2])



# Adjust layout and save the figure
plt.subplots_adjust(wspace=0.3, hspace=0.35)

#panel title
#ax1.set_title('$N=20$', fontsize=40)
#ax2.set_title('$r=0.9$', fontsize=40)
#ax3.set_title('$r=1.3$', fontsize=40)

##axes labels
#axs[0,0].set_xlabel('$r$',fontsize=30)
ax1.set_xlabel('$r$',fontsize=45)
ax2.set_xlabel('$w$',fontsize=45)
ax3.set_xlabel('$w$',fontsize=45)

#axs[0,0].set_ylabel('Difference from Moran',fontsize=30)
#axs[0,1].set_ylabel('$r$',fontsize=25)
ax2.set_ylabel('$N_1$',fontsize=45)
ax3.set_ylabel('$N_1$',fontsize=45)

#axs[0,0].tick_params(axis='x', labelsize=20)
ax2.tick_params(axis='x', labelsize=30) 
ax1.tick_params(axis='x', labelsize=30) 
ax3.tick_params(axis='x', labelsize=30)
#axs[0,0].tick_params(axis='y', labelsize=20)
ax2.tick_params(axis='y', labelsize=30) 
ax1.tick_params(axis='y', labelsize=30) 
ax3.tick_params(axis='y', labelsize=30)# Change xtick label size
# Adjust layout and save the figure
#plt.tight_layout()
#ticklabels
ax1.set_xticks([0.6+k*0.4 for k in range(0,4)])
ax1.set_xticklabels(['0.6','1','1.4','1.8'])
# labels
fig.text(0.1-0.01, 0.9, '(a)', fontsize=40)
fig.text(0.536-0.01, 0.9, '(b)', fontsize=40)
fig.text(0.1-0.01, 0.46, '(c)', fontsize=40)
fig.text(0.536-0.01, 0.46, '(d)', fontsize=40)

fig.text(0.15, 0.16, '$r=0.9$', fontsize=40)
fig.text(0.5996, 0.16, '$r=1.3$', fontsize=40)

cbar1.set_ticks([-0.0016+k*0.0001 for k in range(5)])  # Set tick positions
cbar1.set_ticklabels([str(-0.0016+k*0.0001) for k in range(4)]+['-0.0012'])  # Set tick labels
cbar2.set_ticks([0.12+k*0.01 for k in range(6)])  # Set tick positions
#cbar2.set_ticklabels([str(0.12+k*0.01) for k in range(6)])  # Set tick labels
# Position calculation for the arrow to point at the transition value on the colorbar
# Normalize the transition value within the colorbar's range to get the relative position
norm_value = (level_to_mark1 - norm.vmin) / (norm.vmax - norm.vmin)
# Ensure the normalized value is within the [0,1] range to accurately place the arrow
norm_value = max(0, min(norm_value, 1))

# Annotating with an arrow pointing to the transition value
cbar1.ax.annotate(
    '', 
    xy=(1, norm_value), xycoords='axes fraction',
    xytext=(45, 30), textcoords='offset points',
    arrowprops=dict(arrowstyle="->", color='black', lw=2.25),
    ha='left', va='center'
)

# For the second colorbar, calculating the normalized position of the transition value
norm_value2 = (level_to_mark2 - norm1.vmin) / (norm1.vmax - norm1.vmin)
# Ensure the normalized value is within the [0,1] range to accurately place the arrow
norm_value2 = max(0, min(norm_value2, 1))

# Annotating with an arrow pointing to the transition value on the second colorbar
cbar2.ax.annotate(
    '', 
    xy=(1, norm_value2), xycoords='axes fraction',
    xytext=(45, 30), textcoords='offset points',  # Adjusted xytext to move the arrow base away from the tick
    arrowprops=dict(arrowstyle="->", color='black', lw=2.25),
    ha='left', va='center'
)
cbar1.ax.tick_params(labelsize=20)
cbar2.ax.tick_params(labelsize=20)
plt.subplots_adjust(wspace=0.4,hspace=0.3)
#plt.tight_layout()
plt.savefig('weighted_star_20_nodes.pdf', dpi=300, bbox_inches='tight')
# Show the figure
plt.show()

# %%
[str(-0.0016+k*0.0001) for k in range(4)]+['-0.0012']
# Out:
# ['-0.0016', '-0.0015', '-0.0014', '-0.0013', '-0.0012']

# %%
w_40_star[0][2:39, 2:50].min()
# Out:
# -0.0016006261041417516

# %%
w_40_star[1][2:39, 2:50].max()
# Out:
# 0.16321891926582624

# %%
w_40_star[0][12][15] -0.0015935962097524228
# Out:
# 3.8843905323109225e-07

# %%
0.15993081805569867

# %%
colors = ["blue", "white", "red"]
